# %%
import requests

url = "https://yahoo-finance15.p.rapidapi.com/api/yahoo/qu/quote/AAPL/institution-ownership"

headers = {
	"X-RapidAPI-Key": "06ac5ca0e8msh54d5b1db003ae49p10733bjsn41a386c3dcc4",
	"X-RapidAPI-Host": "yahoo-finance15.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#     "institutionOwnership": {
#         "maxAge": 1,
#         "ownershipList": [
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Vanguard Group, Inc. (The)",
#                 "pctHeld": {
#                     "raw": 0.0808,
#                     "fmt": "8.08%"
#                 },
#                 "position": {
#                     "raw": 1278250538,
#                     "fmt": "1.28B",
#                     "longFmt": "1,278,250,538"
#                 },
#                 "value": {
#                     "raw": 202385410022,
#                     "fmt": "202.39B",
#                     "longFmt": "202,385,410,022"
#                 },
#                 "pctChange": {
#                     "raw": 0.0046,
#                     "fmt": "0.46%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Blackrock Inc.",
#                 "pctHeld": {
#                     "raw": 0.065,
#                     "fmt": "6.50%"
#                 },
#                 "position": {
#                     "raw": 1029208322,
#                     "fmt": "1.03B",
#                     "longFmt": "1,029,208,322"
#                 },
#                 "value": {
#                     "raw": 162954555506,
#                     "fmt": "162.95B",
#                     "longFmt": "162,954,555,506"
#                 },
#                 "pctChange": {
#                     "raw": 0.0088,
#                     "fmt": "0.88%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Berkshire Hathaway, Inc",
#                 "pctHeld": {
#                     "raw": 0.056599997,
#                     "fmt": "5.66%"
#                 },
#                 "position": {
#                     "raw": 895136175,
#                     "fmt": "895.14M",
#                     "longFmt": "895,136,175"
#                 },
#                 "value": {
#                     "raw": 141726912226,
#                     "fmt": "141.73B",
#                     "longFmt": "141,726,912,226"
#                 },
#                 "pctChange": {
#                     "raw": 0.0004,
#                     "fmt": "0.04%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "State Street Corporation",
#                 "pctHeld": {
#                     "raw": 0.037100002,
#                     "fmt": "3.71%"
#                 },
#                 "position": {
#                     "raw": 586857405,
#                     "fmt": "586.86M",
#                     "longFmt": "586,857,405"
#                 },
#                 "value": {
#                     "raw": 92917134008,
#                     "fmt": "92.92B",
#                     "longFmt": "92,917,134,008"
#                 },
#                 "pctChange": {
#                     "raw": -0.007900001,
#                     "fmt": "-0.79%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "FMR, LLC",
#                 "pctHeld": {
#                     "raw": 0.020299999,
#                     "fmt": "2.03%"
#                 },
#                 "position": {
#                     "raw": 321162411,
#                     "fmt": "321.16M",
#                     "longFmt": "321,162,411"
#                 },
#                 "value": {
#                     "raw": 50849645121,
#                     "fmt": "50.85B",
#                     "longFmt": "50,849,645,121"
#                 },
#                 "pctChange": {
#                     "raw": -0.0847,
#                     "fmt": "-8.47%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Geode Capital Management, LLC",
#                 "pctHeld": {
#                     "raw": 0.0179,
#                     "fmt": "1.79%"
#                 },
#                 "position": {
#                     "raw": 282749817,
#                     "fmt": "282.75M",
#                     "longFmt": "282,749,817"
#                 },
#                 "value": {
#                     "raw": 44767779043,
#                     "fmt": "44.77B",
#                     "longFmt": "44,767,779,043"
#                 },
#                 "pctChange": {
#                     "raw": 0.0107,
#                     "fmt": "1.07%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Price (T.Rowe) Associates Inc",
#                 "pctHeld": {
#                     "raw": 0.0143,
#                     "fmt": "1.43%"
#                 },
#                 "position": {
#                     "raw": 226281368,
#                     "fmt": "226.28M",
#                     "longFmt": "226,281,368"
#                 },
#                 "value": {
#                     "raw": 35827129409,
#                     "fmt": "35.83B",
#                     "longFmt": "35,827,129,409"
#                 },
#                 "pctChange": {
#                     "raw": 0.0063,
#                     "fmt": "0.63%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Morgan Stanley",
#                 "pctHeld": {
#                     "raw": 0.013200001,
#                     "fmt": "1.32%"
#                 },
#                 "position": {
#                     "raw": 208655323,
#                     "fmt": "208.66M",
#                     "longFmt": "208,655,323"
#                 },
#                 "value": {
#                     "raw": 33036397672,
#                     "fmt": "33.04B",
#                     "longFmt": "33,036,397,672"
#                 },
#                 "pctChange": {
#                     "raw": 0.1419,
#                     "fmt": "14.19%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Northern Trust Corporation",
#                 "pctHeld": {
#                     "raw": 0.011,
#                     "fmt": "1.10%"
#                 },
#                 "position": {
#                     "raw": 174276229,
#                     "fmt": "174.28M",
#                     "longFmt": "174,276,229"
#                 },
#                 "value": {
#                     "raw": 27593155656,
#                     "fmt": "27.59B",
#                     "longFmt": "27,593,155,656"
#                 },
#                 "pctChange": {
#                     "raw": -0.010299999,
#                     "fmt": "-1.03%"
#                 }
#             },
#             {
#                 "maxAge": 1,
#                 "reportDate": {
#                     "raw": 1672444800,
#                     "fmt": "2022-12-31"
#                 },
#                 "organization": "Norges Bank Investment Management",
#                 "pctHeld": {
#                     "raw": 0.0106,
#                     "fmt": "1.06%"
#                 },
#                 "position": {
#                     "raw": 167374278,
#                     "fmt": "167.37M",
#                     "longFmt": "167,374,278"
#                 },
#                 "value": {
#                     "raw": 26500369742,
#                     "fmt": "26.5B",
#                     "longFmt": "26,500,369,742"
#                 },
#                 "pctChange": {
#                     "raw": 1,
#                     "fmt": "100.00%"
#                 }
#             }
#         ]
#     }
# }

# %%
import pandas as pd
